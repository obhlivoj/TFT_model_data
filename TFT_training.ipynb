# %% [markdown]
# # Info
#
# Training and fine-tuning of Transfromer model.

# %%
import os
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import matplotlib.pyplot as plt

import torch

import lightning.pytorch as pl
from lightning.pytorch.callbacks.early_stopping import EarlyStopping
from lightning.pytorch.callbacks import LearningRateMonitor, Callback, ModelCheckpoint
from pytorch_forecasting import TemporalFusionTransformer, TimeSeriesDataSet
from pytorch_forecasting.metrics import QuantileLoss
from pytorch_forecasting.models.temporal_fusion_transformer.tuning import optimize_hyperparameters

import pickle

# %%
import tensorboard as tb

# %%
with open('./data/input_data.pkl', 'rb') as f:
  input_data = pickle.load(f)

merged_df, training, train_dataloader, validation, val_dataloader = input_data

# %%
RUN_NAME = 'run01'

# %%
class LossLogger(Callback):
    """PyTorch Lightning metric callback."""
    def __init__(self):
        self.train_loss = []
        self.val_loss = []
        self.log_path = f'./{RUN_NAME}/loss_logs'

        if not os.path.exists(self.log_path):
          os.makedirs(self.log_path)

    def write_in_log(self, txt_file, log):
        with open(txt_file, 'a') as file:
            file.write(f'{log}\n')

    def on_train_epoch_end(self, trainer: pl.Trainer, pl_module: pl.LightningModule) -> None:
        train_loss = float(trainer.callback_metrics["train_loss"])
        self.train_loss.append(train_loss)
        self.write_in_log(f"{self.log_path}/training_loss.txt", train_loss)

    def on_validation_epoch_end(self, trainer: pl.Trainer, pl_module: pl.LightningModule) -> None:
        val_loss = float(trainer.callback_metrics["val_loss"])
        self.val_loss.append(val_loss)
        self.write_in_log(f"{self.log_path}/validation_loss.txt", val_loss)

# %%
early_stop_callback = EarlyStopping(monitor="val_loss", min_delta=1e-4, patience=10, verbose=False, mode="min")
checkpoint_callback = ModelCheckpoint(
    monitor='val_loss',
    dirpath=f'./{RUN_NAME}/checkpoint',
    filename='tft-{epoch:02d}-{val_loss:.2f}'
    )
lr_logger = LearningRateMonitor()
val_logger = LossLogger()

trainer = pl.Trainer(
    max_epochs=5,
    accelerator="gpu",
    enable_model_summary=True,
    gradient_clip_val=0.5,
    #limit_train_batches=5,  # coment in for training, running valiation every 30 batches
    # fast_dev_run=True,  # comment in to check that networkor dataset has no serious bugs
    num_sanity_val_steps=0,
    callbacks=[lr_logger, early_stop_callback, val_logger, checkpoint_callback]
)

tft = TemporalFusionTransformer.from_dataset(
    training,
    learning_rate= 0.015,
    hidden_size=32,
    attention_head_size=2,
    dropout=0.25,
    hidden_continuous_size=1,
    lstm_layers = 2,
    loss=QuantileLoss(),
    optimizer="Ranger",
    reduce_on_plateau_patience=4,
)
print(f"Number of parameters in network: {tft.size()/1e3:.1f}k")
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Number of parameters in network: 142.3k

# %%
trainer.fit(
        tft,
        train_dataloaders=train_dataloader,
        val_dataloaders=val_dataloader,
    )
best_model_path = trainer.checkpoint_callback.best_model_path
best_tft = TemporalFusionTransformer.load_from_checkpoint(best_model_path)
# Out:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#    | Name                               | Type                            | Params
# ----------------------------------------------------------------------------------------
# 0  | loss                               | QuantileLoss                    | 0
# 1  | logging_metrics                    | ModuleList                      | 0
# 2  | input_embeddings                   | MultiEmbedding                  | 13
# 3  | prescalers                         | ModuleDict                      | 176
# 4  | static_variable_selection          | VariableSelectionNetwork        | 936
# 5  | encoder_variable_selection         | VariableSelectionNetwork        | 36.5 K
# 6  | decoder_variable_selection         | VariableSelectionNetwork        | 34.5 K
# 7  | static_context_variable_selection  | GatedResidualNetwork            | 4.3 K
# 8  | static_context_initial_hidden_lstm | GatedResidualNetwork            | 4.3 K
# 9  | static_context_initial_cell_lstm   | GatedResidualNetwork            | 4.3 K
# 10 | static_context_enrichment          | GatedResidualNetwork            | 4.3 K
# 11 | lstm_encoder                       | LSTM                            | 16.9 K
# 12 | lstm_decoder                       | LSTM                            | 16.9 K
# 13 | post_lstm_gate_encoder             | GatedLinearUnit                 | 2.1 K
# 14 | post_lstm_add_norm_encoder         | AddNorm                         | 64
# 15 | static_enrichment                  | GatedResidualNetwork            | 5.3 K
# 16 | multihead_attn                     | InterpretableMultiHeadAttention | 3.2 K
# 17 | post_attn_gate_norm                | GateAddNorm                     | 2.2 K
# 18 | pos_wise_ff                        | GatedResidualNetwork            | 4.3 K
# 19 | pre_output_gate_norm               | GateAddNorm                     | 2.2 K
# 20 | output_layer                       | Linear                          | 231
# ----------------------------------------------------------------------------------------
# 142 K     Trainable params
# 0         Non-trainable params
# 142 K     Total params
# 0.569     Total estimated model params size (MB)
# Epoch 4: 100%|██████████| 671/671 [18:15<00:00,  1.63s/it, v_num=4, train_loss_step=56.00, val_loss=64.70, train_loss_epoch=60.80]
# `Trainer.fit` stopped: `max_epochs=5` reached.
# Epoch 4: 100%|██████████| 671/671 [18:18<00:00,  1.64s/it, v_num=4, train_loss_step=56.00, val_loss=64.70, train_loss_epoch=60.80]

# %%
optuna_train_dataloader = training.to_dataloader(train=True, batch_size=128, shuffle=True)
optuna_val_dataloader = validation.to_dataloader(train=False, batch_size=512, shuffle=True)

# %%
# create study
study = optimize_hyperparameters(
    train_dataloader,
    val_dataloader,
    model_path="optuna_test",
    n_trials=10,
    max_epochs=5,
    gradient_clip_val_range=(0.3, 0.8),
    hidden_size_range=(96, 128),
    hidden_continuous_size_range=(8, 16),
    attention_head_size_range=(2, 4),
    learning_rate_range=(0.012, 0.015),
    dropout_range=(0.15, 0.25),
    #trainer_kwargs=dict(limit_train_batches=30),
    reduce_on_plateau_patience=4,
    use_learning_rate_finder=False,
)

# save study results - also we can resume tuning at a later point in time
with open("test_study.pkl", "wb") as fout:
    pickle.dump(study, fout)

# show best hyperparameters
print(study.best_trial.params)
# Out:
# [I 2023-10-08 14:38:11,638] A new study created in memory with name: no-name-21253672-daec-4fe4-9626-8b7d73b0dc3c
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# `Trainer.fit` stopped: `max_epochs=5` reached.
# [I 2023-10-08 16:09:05,326] Trial 0 finished with value: 63.283077239990234 and parameters: {'gradient_clip_val': 0.3512658685281037, 'hidden_size': 120, 'dropout': 0.19489238631571226, 'hidden_continuous_size': 10, 'attention_head_size': 2, 'learning_rate': 0.014504876575252557}. Best is trial 0 with value: 63.283077239990234.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# `Trainer.fit` stopped: `max_epochs=5` reached.
# [I 2023-10-08 17:36:17,497] Trial 1 finished with value: 63.47090530395508 and parameters: {'gradient_clip_val': 0.4086660721160471, 'hidden_size': 96, 'dropout': 0.16779202946069072, 'hidden_continuous_size': 11, 'attention_head_size': 4, 'learning_rate': 0.013807293612020646}. Best is trial 0 with value: 63.283077239990234.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# `Trainer.fit` stopped: `max_epochs=5` reached.
# [I 2023-10-08 19:05:49,558] Trial 2 finished with value: 63.94034194946289 and parameters: {'gradient_clip_val': 0.3698466431042652, 'hidden_size': 107, 'dropout': 0.22022650251157327, 'hidden_continuous_size': 8, 'attention_head_size': 2, 'learning_rate': 0.012098409784569412}. Best is trial 0 with value: 63.283077239990234.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# `Trainer.fit` stopped: `max_epochs=5` reached.
# [I 2023-10-08 20:35:17,910] Trial 3 finished with value: 62.577537536621094 and parameters: {'gradient_clip_val': 0.39555291008313737, 'hidden_size': 96, 'dropout': 0.22720900508640027, 'hidden_continuous_size': 9, 'attention_head_size': 3, 'learning_rate': 0.013729308543072971}. Best is trial 3 with value: 62.577537536621094.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# `Trainer.fit` stopped: `max_epochs=5` reached.
# [I 2023-10-08 22:03:58,252] Trial 4 finished with value: 64.05943298339844 and parameters: {'gradient_clip_val': 0.5989127556199371, 'hidden_size': 128, 'dropout': 0.23637078582058854, 'hidden_continuous_size': 15, 'attention_head_size': 3, 'learning_rate': 0.012028205352200243}. Best is trial 3 with value: 62.577537536621094.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# `Trainer.fit` stopped: `max_epochs=5` reached.
# [I 2023-10-08 23:32:50,543] Trial 5 finished with value: 63.84231185913086 and parameters: {'gradient_clip_val': 0.7656710326002976, 'hidden_size': 103, 'dropout': 0.23852317071379808, 'hidden_continuous_size': 13, 'attention_head_size': 4, 'learning_rate': 0.012083233137543885}. Best is trial 3 with value: 62.577537536621094.
# {'gradient_clip_val': 0.39555291008313737, 'hidden_size': 96, 'dropout': 0.22720900508640027, 'hidden_continuous_size': 9, 'attention_head_size': 3, 'learning_rate': 0.013729308543072971}

# %%
study.trials
# Out:
# [FrozenTrial(number=0, state=TrialState.COMPLETE, values=[63.283077239990234], datetime_start=datetime.datetime(2023, 10, 8, 14, 38, 11, 639017), datetime_complete=datetime.datetime(2023, 10, 8, 16, 9, 5, 326841), params={'gradient_clip_val': 0.3512658685281037, 'hidden_size': 120, 'dropout': 0.19489238631571226, 'hidden_continuous_size': 10, 'attention_head_size': 2, 'learning_rate': 0.014504876575252557}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'gradient_clip_val': FloatDistribution(high=0.8, log=True, low=0.3, step=None), 'hidden_size': IntDistribution(high=128, log=True, low=96, step=1), 'dropout': FloatDistribution(high=0.25, log=False, low=0.15, step=None), 'hidden_continuous_size': IntDistribution(high=16, log=True, low=8, step=1), 'attention_head_size': IntDistribution(high=4, log=False, low=2, step=1), 'learning_rate': FloatDistribution(high=0.015, log=True, low=0.012, step=None)}, trial_id=0, value=None),
#  FrozenTrial(number=1, state=TrialState.COMPLETE, values=[63.47090530395508], datetime_start=datetime.datetime(2023, 10, 8, 16, 9, 5, 327840), datetime_complete=datetime.datetime(2023, 10, 8, 17, 36, 17, 496222), params={'gradient_clip_val': 0.4086660721160471, 'hidden_size': 96, 'dropout': 0.16779202946069072, 'hidden_continuous_size': 11, 'attention_head_size': 4, 'learning_rate': 0.013807293612020646}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'gradient_clip_val': FloatDistribution(high=0.8, log=True, low=0.3, step=None), 'hidden_size': IntDistribution(high=128, log=True, low=96, step=1), 'dropout': FloatDistribution(high=0.25, log=False, low=0.15, step=None), 'hidden_continuous_size': IntDistribution(high=16, log=True, low=8, step=1), 'attention_head_size': IntDistribution(high=4, log=False, low=2, step=1), 'learning_rate': FloatDistribution(high=0.015, log=True, low=0.012, step=None)}, trial_id=1, value=None),
#  FrozenTrial(number=2, state=TrialState.COMPLETE, values=[63.94034194946289], datetime_start=datetime.datetime(2023, 10, 8, 17, 36, 17, 497750), datetime_complete=datetime.datetime(2023, 10, 8, 19, 5, 49, 558166), params={'gradient_clip_val': 0.3698466431042652, 'hidden_size': 107, 'dropout': 0.22022650251157327, 'hidden_continuous_size': 8, 'attention_head_size': 2, 'learning_rate': 0.012098409784569412}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'gradient_clip_val': FloatDistribution(high=0.8, log=True, low=0.3, step=None), 'hidden_size': IntDistribution(high=128, log=True, low=96, step=1), 'dropout': FloatDistribution(high=0.25, log=False, low=0.15, step=None), 'hidden_continuous_size': IntDistribution(high=16, log=True, low=8, step=1), 'attention_head_size': IntDistribution(high=4, log=False, low=2, step=1), 'learning_rate': FloatDistribution(high=0.015, log=True, low=0.012, step=None)}, trial_id=2, value=None),
#  FrozenTrial(number=3, state=TrialState.COMPLETE, values=[62.577537536621094], datetime_start=datetime.datetime(2023, 10, 8, 19, 5, 49, 559164), datetime_complete=datetime.datetime(2023, 10, 8, 20, 35, 17, 909956), params={'gradient_clip_val': 0.39555291008313737, 'hidden_size': 96, 'dropout': 0.22720900508640027, 'hidden_continuous_size': 9, 'attention_head_size': 3, 'learning_rate': 0.013729308543072971}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'gradient_clip_val': FloatDistribution(high=0.8, log=True, low=0.3, step=None), 'hidden_size': IntDistribution(high=128, log=True, low=96, step=1), 'dropout': FloatDistribution(high=0.25, log=False, low=0.15, step=None), 'hidden_continuous_size': IntDistribution(high=16, log=True, low=8, step=1), 'attention_head_size': IntDistribution(high=4, log=False, low=2, step=1), 'learning_rate': FloatDistribution(high=0.015, log=True, low=0.012, step=None)}, trial_id=3, value=None),
#  FrozenTrial(number=4, state=TrialState.COMPLETE, values=[64.05943298339844], datetime_start=datetime.datetime(2023, 10, 8, 20, 35, 17, 910935), datetime_complete=datetime.datetime(2023, 10, 8, 22, 3, 58, 252818), params={'gradient_clip_val': 0.5989127556199371, 'hidden_size': 128, 'dropout': 0.23637078582058854, 'hidden_continuous_size': 15, 'attention_head_size': 3, 'learning_rate': 0.012028205352200243}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'gradient_clip_val': FloatDistribution(high=0.8, log=True, low=0.3, step=None), 'hidden_size': IntDistribution(high=128, log=True, low=96, step=1), 'dropout': FloatDistribution(high=0.25, log=False, low=0.15, step=None), 'hidden_continuous_size': IntDistribution(high=16, log=True, low=8, step=1), 'attention_head_size': IntDistribution(high=4, log=False, low=2, step=1), 'learning_rate': FloatDistribution(high=0.015, log=True, low=0.012, step=None)}, trial_id=4, value=None),
#  FrozenTrial(number=5, state=TrialState.COMPLETE, values=[63.84231185913086], datetime_start=datetime.datetime(2023, 10, 8, 22, 3, 58, 253786), datetime_complete=datetime.datetime(2023, 10, 8, 23, 32, 50, 543303), params={'gradient_clip_val': 0.7656710326002976, 'hidden_size': 103, 'dropout': 0.23852317071379808, 'hidden_continuous_size': 13, 'attention_head_size': 4, 'learning_rate': 0.012083233137543885}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'gradient_clip_val': FloatDistribution(high=0.8, log=True, low=0.3, step=None), 'hidden_size': IntDistribution(high=128, log=True, low=96, step=1), 'dropout': FloatDistribution(high=0.25, log=False, low=0.15, step=None), 'hidden_continuous_size': IntDistribution(high=16, log=True, low=8, step=1), 'attention_head_size': IntDistribution(high=4, log=False, low=2, step=1), 'learning_rate': FloatDistribution(high=0.015, log=True, low=0.012, step=None)}, trial_id=5, value=None)]

# %%
trainer.fit(
        tft,
        train_dataloaders=train_dataloader,
        val_dataloaders=val_dataloader,
    )
best_model_path = trainer.checkpoint_callback.best_model_path
best_tft = TemporalFusionTransformer.load_from_checkpoint(best_model_path)
# Out:
# Missing logger folder: d:\Programming\DP\TFT_model_data\lightning_logs
#
#    | Name                               | Type                            | Params
# ----------------------------------------------------------------------------------------
# 0  | loss                               | QuantileLoss                    | 0
# 1  | logging_metrics                    | ModuleList                      | 0
# 2  | input_embeddings                   | MultiEmbedding                  | 13
# 3  | prescalers                         | ModuleDict                      | 176
# 4  | static_variable_selection          | VariableSelectionNetwork        | 936
# 5  | encoder_variable_selection         | VariableSelectionNetwork        | 36.5 K
# 6  | decoder_variable_selection         | VariableSelectionNetwork        | 34.5 K
# 7  | static_context_variable_selection  | GatedResidualNetwork            | 4.3 K
# 8  | static_context_initial_hidden_lstm | GatedResidualNetwork            | 4.3 K
# 9  | static_context_initial_cell_lstm   | GatedResidualNetwork            | 4.3 K
# 10 | static_context_enrichment          | GatedResidualNetwork            | 4.3 K
# 11 | lstm_encoder                       | LSTM                            | 16.9 K
# 12 | lstm_decoder                       | LSTM                            | 16.9 K
# 13 | post_lstm_gate_encoder             | GatedLinearUnit                 | 2.1 K
# 14 | post_lstm_add_norm_encoder         | AddNorm                         | 64
# 15 | static_enrichment                  | GatedResidualNetwork            | 5.3 K
# 16 | multihead_attn                     | InterpretableMultiHeadAttention | 3.2 K
# 17 | post_attn_gate_norm                | GateAddNorm                     | 2.2 K
# 18 | pos_wise_ff                        | GatedResidualNetwork            | 4.3 K
# 19 | pre_output_gate_norm               | GateAddNorm                     | 2.2 K
# 20 | output_layer                       | Linear                          | 231
# ----------------------------------------------------------------------------------------
# 142 K     Trainable params
# 0         Non-trainable params
# 142 K     Total params
# 0.569     Total estimated model params size (MB)
# Epoch 14: 100%|██████████| 671/671 [55:44<00:00,  4.98s/it, v_num=0, train_loss_step=52.50, val_loss=71.20, train_loss_epoch=55.40]

# %%
best_model_path = trainer.checkpoint_callback.best_model_path
best_tft = TemporalFusionTransformer.load_from_checkpoint(best_model_path)

torch.save(best_tft, "tft_model")

# %%
best_tft = torch.load("tft_model")

# %%
best_tft.eval()
raw_prediction = best_tft.predict(
    validation,
    mode="raw",
    return_x=True,
    return_y=True,
    batch_size = 1,
)

# %%
predictions = best_tft.predict(validation, batch_size=1, return_y=True)

# %%
MAE()(predictions.output, predictions.y[0].view(-1,8))
# Out:
# tensor(122.9977)

# %%
RMSE()(predictions.output, predictions.y[0].view(-1,8))
# Out:
# tensor(170.0242)

# %%
predictions.output[0]
# Out:
# tensor([  72.5813,   40.2114,    7.7808,  -11.0756,    2.5228,  -68.9974,
#         -102.8922,  -97.0845])

# %%
raw_prediction.output.prediction[0]
# Out:
# tensor([[-1.3946e+02, -5.1067e+01,  1.6953e+01,  7.2581e+01,  1.2900e+02,
#           1.7845e+02,  2.7298e+02],
#         [-1.6032e+02, -6.7371e+01, -6.5494e+00,  4.0211e+01,  9.6146e+01,
#           1.3674e+02,  2.0958e+02],
#         [-2.3153e+02, -1.2108e+02, -5.5369e+01,  7.7808e+00,  7.4741e+01,
#           1.2882e+02,  2.1492e+02],
#         [-2.1438e+02, -1.3139e+02, -7.1129e+01, -1.1076e+01,  4.4728e+01,
#           8.7666e+01,  1.6946e+02],
#         [-2.1937e+02, -1.2536e+02, -5.8693e+01,  2.5228e+00,  7.0254e+01,
#           1.2052e+02,  2.0638e+02],
#         [-2.9513e+02, -1.8984e+02, -1.3053e+02, -6.8997e+01, -1.7653e+01,
#           2.2576e+01,  9.1551e+01],
#         [-3.8635e+02, -2.6618e+02, -1.9679e+02, -1.0289e+02, -3.5783e+01,
#           2.1523e+01,  1.0396e+02],
#         [-3.2419e+02, -2.2131e+02, -1.6210e+02, -9.7085e+01, -4.4661e+01,
#          -1.6698e-02,  7.1332e+01]])

# %%
raw_prediction.y[0].shape
# Out:
# torch.Size([1, 111560])
