# %% [markdown]
# # Info
#
# Training and fine-tuning of Transfromer model.

# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn-dark-palette')

import torch

import lightning.pytorch as pl
from lightning.pytorch.callbacks.early_stopping import EarlyStopping
from lightning.pytorch.callbacks import LearningRateMonitor
from pytorch_forecasting import TemporalFusionTransformer, TimeSeriesDataSet
from pytorch_forecasting.metrics import QuantileLoss, MAE, RMSE
from pytorch_forecasting.models.temporal_fusion_transformer.tuning import optimize_hyperparameters

import pickle

# %%
with open('./data/input_data.pkl', 'rb') as f:
  input_data = pickle.load(f)

merged_df, training, train_dataloader, validation, val_dataloader = input_data

# %%
early_stop_callback = EarlyStopping(monitor="val_loss", min_delta=1e-4, patience=10, verbose=False, mode="min")
lr_logger = LearningRateMonitor()

trainer = pl.Trainer(
    max_epochs=200,
    accelerator="cpu",
    enable_model_summary=True,
    gradient_clip_val=0.02,
    #limit_train_batches=50,  # coment in for training, running valiation every 30 batches
    # fast_dev_run=True,  # comment in to check that networkor dataset has no serious bugs
    callbacks=[lr_logger, early_stop_callback]
)

tft = TemporalFusionTransformer.from_dataset(
    training,
    learning_rate= 0.001,
    hidden_size=32,
    attention_head_size=2,
    dropout=0.15,
    hidden_continuous_size=1,
    lstm_layers = 2,
    loss=QuantileLoss(),
    optimizer="Ranger",
    reduce_on_plateau_patience=4,
)
print(f"Number of parameters in network: {tft.size()/1e3:.1f}k")
# Out:
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Number of parameters in network: 142.3k

# %%
optuna_train_dataloader = training.to_dataloader(train=True, batch_size=128, shuffle=True)
optuna_val_dataloader = validation.to_dataloader(train=False, batch_size=512, shuffle=True)

# %%
# create study
study = optimize_hyperparameters(
    optuna_train_dataloader,
    val_dataloader,
    model_path="optuna_test",
    n_trials=25,
    max_epochs=5,
    gradient_clip_val_range=(0.3, 0.8),
    hidden_size_range=(96, 128),
    hidden_continuous_size_range=(8, 16),
    attention_head_size_range=(2, 4),
    learning_rate_range=(0.012, 0.015),
    dropout_range=(0.15, 0.25),
    trainer_kwargs=dict(limit_train_batches=30),
    reduce_on_plateau_patience=4,
    use_learning_rate_finder=False,
)

# save study results - also we can resume tuning at a later point in time
with open("test_study.pkl", "wb") as fout:
    pickle.dump(study, fout)

# show best hyperparameters
print(study.best_trial.params)
# Out:
# [I 2023-10-01 10:49:50,653] A new study created in memory with name: no-name-a69f7bcb-359f-4177-ad0d-49b023aace26
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# `Trainer.fit` stopped: `max_epochs=5` reached.
# [I 2023-10-01 11:50:35,616] Trial 0 finished with value: 63.335384368896484 and parameters: {'gradient_clip_val': 0.46880744899588866, 'hidden_size': 121, 'dropout': 0.18457728196359122, 'hidden_continuous_size': 12, 'attention_head_size': 2, 'learning_rate': 0.012471631006971363}. Best is trial 0 with value: 63.335384368896484.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# `Trainer.fit` stopped: `max_epochs=5` reached.
# [I 2023-10-01 12:44:14,522] Trial 1 finished with value: 63.371158599853516 and parameters: {'gradient_clip_val': 0.37293205349987274, 'hidden_size': 108, 'dropout': 0.23872064886177166, 'hidden_continuous_size': 15, 'attention_head_size': 4, 'learning_rate': 0.013711011905991353}. Best is trial 0 with value: 63.335384368896484.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# `Trainer.fit` stopped: `max_epochs=5` reached.
# [I 2023-10-01 13:40:00,784] Trial 2 finished with value: 62.944210052490234 and parameters: {'gradient_clip_val': 0.6986035857479458, 'hidden_size': 117, 'dropout': 0.2441138157228376, 'hidden_continuous_size': 8, 'attention_head_size': 2, 'learning_rate': 0.01397937602930689}. Best is trial 2 with value: 62.944210052490234.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# `Trainer.fit` stopped: `max_epochs=5` reached.
# [I 2023-10-01 14:32:09,566] Trial 3 finished with value: 61.95207214355469 and parameters: {'gradient_clip_val': 0.6237967635603826, 'hidden_size': 104, 'dropout': 0.1669137036299678, 'hidden_continuous_size': 10, 'attention_head_size': 3, 'learning_rate': 0.012029058939689346}. Best is trial 3 with value: 61.95207214355469.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# `Trainer.fit` stopped: `max_epochs=5` reached.
# [I 2023-10-01 15:22:47,243] Trial 4 finished with value: 63.876365661621094 and parameters: {'gradient_clip_val': 0.3575597901595322, 'hidden_size': 98, 'dropout': 0.18783646033433526, 'hidden_continuous_size': 8, 'attention_head_size': 2, 'learning_rate': 0.013229278940635834}. Best is trial 3 with value: 61.95207214355469.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# `Trainer.fit` stopped: `max_epochs=5` reached.
# [I 2023-10-01 16:17:54,200] Trial 5 finished with value: 63.046512603759766 and parameters: {'gradient_clip_val': 0.48119911530150655, 'hidden_size': 119, 'dropout': 0.2021464003178048, 'hidden_continuous_size': 11, 'attention_head_size': 2, 'learning_rate': 0.01284773821411369}. Best is trial 3 with value: 61.95207214355469.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# `Trainer.fit` stopped: `max_epochs=5` reached.
# [I 2023-10-01 17:13:09,899] Trial 6 finished with value: 63.91054916381836 and parameters: {'gradient_clip_val': 0.3228510910834292, 'hidden_size': 118, 'dropout': 0.19668739162103094, 'hidden_continuous_size': 13, 'attention_head_size': 3, 'learning_rate': 0.013829541998254527}. Best is trial 3 with value: 61.95207214355469.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# `Trainer.fit` stopped: `max_epochs=5` reached.
# [I 2023-10-01 18:08:59,396] Trial 7 finished with value: 61.834476470947266 and parameters: {'gradient_clip_val': 0.5954558734996294, 'hidden_size': 123, 'dropout': 0.16398943569323365, 'hidden_continuous_size': 8, 'attention_head_size': 4, 'learning_rate': 0.013179919059645011}. Best is trial 7 with value: 61.834476470947266.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# `Trainer.fit` stopped: `max_epochs=5` reached.
# [I 2023-10-01 19:02:07,531] Trial 8 finished with value: 62.97340774536133 and parameters: {'gradient_clip_val': 0.4583579166797815, 'hidden_size': 116, 'dropout': 0.15741036825590338, 'hidden_continuous_size': 12, 'attention_head_size': 4, 'learning_rate': 0.012602234329968508}. Best is trial 7 with value: 61.834476470947266.
# {'gradient_clip_val': 0.5954558734996294, 'hidden_size': 123, 'dropout': 0.16398943569323365, 'hidden_continuous_size': 8, 'attention_head_size': 4, 'learning_rate': 0.013179919059645011}

# %%
trainer.fit(
        tft,
        train_dataloaders=train_dataloader,
        val_dataloaders=val_dataloader,
    )
best_model_path = trainer.checkpoint_callback.best_model_path
best_tft = TemporalFusionTransformer.load_from_checkpoint(best_model_path)
# Out:
# Missing logger folder: d:\Programming\DP\TFT_model_data\lightning_logs
#
#    | Name                               | Type                            | Params
# ----------------------------------------------------------------------------------------
# 0  | loss                               | QuantileLoss                    | 0
# 1  | logging_metrics                    | ModuleList                      | 0
# 2  | input_embeddings                   | MultiEmbedding                  | 13
# 3  | prescalers                         | ModuleDict                      | 176
# 4  | static_variable_selection          | VariableSelectionNetwork        | 936
# 5  | encoder_variable_selection         | VariableSelectionNetwork        | 36.5 K
# 6  | decoder_variable_selection         | VariableSelectionNetwork        | 34.5 K
# 7  | static_context_variable_selection  | GatedResidualNetwork            | 4.3 K
# 8  | static_context_initial_hidden_lstm | GatedResidualNetwork            | 4.3 K
# 9  | static_context_initial_cell_lstm   | GatedResidualNetwork            | 4.3 K
# 10 | static_context_enrichment          | GatedResidualNetwork            | 4.3 K
# 11 | lstm_encoder                       | LSTM                            | 16.9 K
# 12 | lstm_decoder                       | LSTM                            | 16.9 K
# 13 | post_lstm_gate_encoder             | GatedLinearUnit                 | 2.1 K
# 14 | post_lstm_add_norm_encoder         | AddNorm                         | 64
# 15 | static_enrichment                  | GatedResidualNetwork            | 5.3 K
# 16 | multihead_attn                     | InterpretableMultiHeadAttention | 3.2 K
# 17 | post_attn_gate_norm                | GateAddNorm                     | 2.2 K
# 18 | pos_wise_ff                        | GatedResidualNetwork            | 4.3 K
# 19 | pre_output_gate_norm               | GateAddNorm                     | 2.2 K
# 20 | output_layer                       | Linear                          | 231
# ----------------------------------------------------------------------------------------
# 142 K     Trainable params
# 0         Non-trainable params
# 142 K     Total params
# 0.569     Total estimated model params size (MB)
# Epoch 14: 100%|██████████| 671/671 [55:44<00:00,  4.98s/it, v_num=0, train_loss_step=52.50, val_loss=71.20, train_loss_epoch=55.40]

# %%
best_model_path = trainer.checkpoint_callback.best_model_path
best_tft = TemporalFusionTransformer.load_from_checkpoint(best_model_path)

torch.save(best_tft, "tft_model")

# %%
best_tft = torch.load("tft_model")

# %%
best_tft.eval()
raw_prediction = best_tft.predict(
    validation,
    mode="raw",
    return_x=True,
    return_y=True,
    batch_size = 1,
)

# %%
predictions = best_tft.predict(validation, batch_size=1, return_y=True)

# %%
MAE()(predictions.output, predictions.y[0].view(-1,8))
# Out:
# tensor(122.9977)

# %%
RMSE()(predictions.output, predictions.y[0].view(-1,8))
# Out:
# tensor(170.0242)

# %%
predictions.output[0]
# Out:
# tensor([  72.5813,   40.2114,    7.7808,  -11.0756,    2.5228,  -68.9974,
#         -102.8922,  -97.0845])

# %%
raw_prediction.output.prediction[0]
# Out:
# tensor([[-1.3946e+02, -5.1067e+01,  1.6953e+01,  7.2581e+01,  1.2900e+02,
#           1.7845e+02,  2.7298e+02],
#         [-1.6032e+02, -6.7371e+01, -6.5494e+00,  4.0211e+01,  9.6146e+01,
#           1.3674e+02,  2.0958e+02],
#         [-2.3153e+02, -1.2108e+02, -5.5369e+01,  7.7808e+00,  7.4741e+01,
#           1.2882e+02,  2.1492e+02],
#         [-2.1438e+02, -1.3139e+02, -7.1129e+01, -1.1076e+01,  4.4728e+01,
#           8.7666e+01,  1.6946e+02],
#         [-2.1937e+02, -1.2536e+02, -5.8693e+01,  2.5228e+00,  7.0254e+01,
#           1.2052e+02,  2.0638e+02],
#         [-2.9513e+02, -1.8984e+02, -1.3053e+02, -6.8997e+01, -1.7653e+01,
#           2.2576e+01,  9.1551e+01],
#         [-3.8635e+02, -2.6618e+02, -1.9679e+02, -1.0289e+02, -3.5783e+01,
#           2.1523e+01,  1.0396e+02],
#         [-3.2419e+02, -2.2131e+02, -1.6210e+02, -9.7085e+01, -4.4661e+01,
#          -1.6698e-02,  7.1332e+01]])

# %%
raw_prediction.y[0].shape
# Out:
# torch.Size([1, 111560])
